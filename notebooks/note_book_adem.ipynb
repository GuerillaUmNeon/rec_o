# %%
import sys

# !{sys.executable} -m pip install python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv

print("dotenv OK")
# Out:
# dotenv OK

# %%
import os
import psycopg2
from dotenv import load_dotenv

load_dotenv("../.env")

conn = psycopg2.connect(
    host=os.getenv("POSTGRES"),
    port=5432,
    database=os.getenv("DATABASE"),
    user=os.getenv("DB_USERNAME"),
    password=os.getenv("DB_PASSWORD")
)

print("Connexion OK")
# Out:
# Connexion OK

# %%
import pandas as pd

query = """
SELECT
    a.name AS artist_name,
    rg.name AS album_name
FROM musicbrainz.l_artist_release_group l
JOIN musicbrainz.artist a
    ON l.entity0 = a.id
JOIN musicbrainz.release_group rg
    ON l.entity1 = rg.id
LIMIT 20;
"""

df = pd.read_sql(query, conn)

df
# Out:
# /var/folders/yn/fvh46w1d6tv6lxys_3t_l2rr0000gn/T/ipykernel_17740/2449627440.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#             artist_name                                         album_name
# 0         Sopa de Cabra    Podré tornar enrere. El tribut a Sopa de Cabra.
# 1        John Malm, Jr.                                   Head Like a Hole
# 2         Päkkos Gustaf  Bingsjö by Anders Bjernulf, a tribute to Päkko...
# 3        John Malm, Jr.                                         Down in It
# 4   Ben “Lambo” Lambert                                            Alfredo
# 5             Andy Siry                                   Serenity in Fire
# 6       Nine Inch Nails  Special Tribute to Nine Inch Nails: Soundtrack...
# ...

# %%
print(conn.closed)
# Out:
# 0

# %%
import pandas as pd

query = """
SELECT
    a.name AS artist_name,
    rg.name AS album_name
FROM musicbrainz.l_artist_release_group l
JOIN musicbrainz.artist a
    ON l.entity0 = a.id
JOIN musicbrainz.release_group rg
    ON l.entity1 = rg.id
LIMIT 20;
"""

df = pd.read_sql(query, conn)

df
# Out:
# /var/folders/yn/fvh46w1d6tv6lxys_3t_l2rr0000gn/T/ipykernel_17740/2449627440.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
#             artist_name                                         album_name
# 0         Sopa de Cabra    Podré tornar enrere. El tribut a Sopa de Cabra.
# 1        John Malm, Jr.                                   Head Like a Hole
# 2         Päkkos Gustaf  Bingsjö by Anders Bjernulf, a tribute to Päkko...
# 3        John Malm, Jr.                                         Down in It
# 4   Ben “Lambo” Lambert                                            Alfredo
# 5             Andy Siry                                   Serenity in Fire
# 6       Nine Inch Nails  Special Tribute to Nine Inch Nails: Soundtrack...
# ...
